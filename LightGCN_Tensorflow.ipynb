# %% [markdown]
# # Link source code

# %% [markdown]
# https://github.com/kuandeng/LightGCN

# %%
# !git clone https://---personal acess token---@github.com/Binh707/BMMS-AI-Tensorflow.git
# Out:
# Cloning into 'BMMS-AI-Tensorflow'...
# remote: Enumerating objects: 433, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 433 (delta 4), reused 29 (delta 4), pack-reused 399
# Receiving objects: 100% (433/433), 251.47 MiB | 20.42 MiB/s, done.
# Resolving deltas: 100% (155/155), done.
# Updating files: 100% (72/72), done.

# %%
# !ls
# !pwd 
# %cd BMMS-AI-Tensorflow/
# !ls

#!pip install -r requirements.txt
# Out:
# BMMS-AI-Tensorflow  sample_data
# /content
# /content/BMMS-AI-Tensorflow
# Data	   LightGCN.py	README.md  tensorboard	weights
# evaluator  output	setup.py   utility

# %% [markdown]
# # Install

# %%
# !pip install tensorflow #==1.11.0
# %tensorflow_version 1.11.0

# !pip install numpy  #==1.14.3
# !pip install scipy  #==1.1.0
# !pip install scikit-learn  #==0.19.1
# !pip install cython #==0.29.15
# !pip install tensorboardX
# !pip install scikit-learn
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python setup.py build_ext --inplace
# Out:
# ...
# Compiling apt_evaluate_foldout.pyx because it changed.
# Compiling apt_tools.pyx because it changed.
# [1/2] Cythonizing apt_evaluate_foldout.pyx
# /usr/local/lib/python3.9/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/BMMS-AI-Tensorflow/evaluator/cpp/apt_evaluate_foldout.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [2/2] Cythonizing apt_tools.pyx
# /usr/local/lib/python3.9/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/BMMS-AI-Tensorflow/evaluator/cpp/apt_tools.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'apt_evaluate_foldout' extension
# ...

# %% [markdown]
# # Training

# %% [markdown]
# Chỉ cần sửa tham số:
# * --dataset (bộ dataset: movielens-100k / hetrec2011-MovieLens-2k
# * --layer_size (số layer: [64] / [64,64,64])
# * ----alg_type (mô hình: ngcf / lightgcn)

# %%
# !python LightGCN.py --dataset gowalla --regs [1e-4] --embed_size 64 --layer_size [64] --alg_type ngcf --lr 0.001 --batch_size 2048 --epoch 40 --save_flag 1 --pretrain 1
# Out:
# 2023-03-29 07:48:35.033990: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-29 07:48:36.066690: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-29 07:48:36.066806: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# # Update

# %%
# !git config --global user.email "---.com"
# !git config --global user.name "----"

# %%
# !git add -A

# %%
# !git commit -m "____"
# !git push -u origin master
# Out:
# [master a9cd714] Test ngcf
#  8 files changed, 4 deletions(-)
#  delete mode 100644 weights/gowalla/LightGCN/64-64/l0.001_r0.0001/checkpoint
#  delete mode 100644 weights/gowalla/LightGCN/64-64/l0.001_r0.0001/weights-100.data-00000-of-00001
#  delete mode 100644 weights/gowalla/LightGCN/64-64/l0.001_r0.0001/weights-100.index
#  delete mode 100644 weights/gowalla/LightGCN/64-64/l0.001_r0.0001/weights-100.meta
#  delete mode 100644 weights/gowalla/LightGCN/64/l0.001_r0.0001/checkpoint
#  delete mode 100644 weights/gowalla/LightGCN/64/l0.001_r0.0001/weights-20.data-00000-of-00001
#  delete mode 100644 weights/gowalla/LightGCN/64/l0.001_r0.0001/weights-20.index
#  delete mode 100644 weights/gowalla/LightGCN/64/l0.001_r0.0001/weights-20.meta
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 218 bytes | 218.00 KiB/s, done.
# ...
